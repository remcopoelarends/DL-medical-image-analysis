# %%
# !pip install SimpleITK
# !pip install opencv-python
# !pip install segmentation-models-pytorch
# !pip install monai
# !pip install torch==1.8.0+cu111 torchvision==0.9.0+cu111 torchaudio==0.8.0 -f https://download.pytorch.org/whl/torch_stable.html
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: SimpleITK in /home/jovyan/.local/lib/python3.8/site-packages (2.2.1)
# Defaulting to user installation because normal site-packages is not writeable
# Collecting opencv-python
#   Downloading opencv_python-4.7.0.72-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (61.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.8/61.8 MB 19.3 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: numpy>=1.17.0 in /usr/local/lib/python3.8/dist-packages (from opencv-python) (1.23.1)
# Installing collected packages: opencv-python
# Successfully installed opencv-python-4.7.0.72
# Defaulting to user installation because normal site-packages is not writeable
# Collecting segmentation-models-pytorch
#   Downloading segmentation_models_pytorch-0.3.2-py3-none-any.whl (106 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 106.7/106.7 kB 1.8 MB/s eta 0:00:00a 0:00:01
# Requirement already satisfied: torchvision>=0.5.0 in /home/jovyan/.local/lib/python3.8/site-packages (from segmentation-models-pytorch) (0.15.2+cu117)
# Collecting pretrainedmodels==0.7.4 (from segmentation-models-pytorch)
#   Downloading pretrainedmodels-0.7.4.tar.gz (58 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.8/58.8 kB 495.9 kB/s eta 0:00:00a 0:00:01
#   Preparing metadata (setup.py) ... done
# Collecting efficientnet-pytorch==0.7.1 (from segmentation-models-pytorch)
#   Downloading efficientnet_pytorch-0.7.1.tar.gz (21 kB)
#   Preparing metadata (setup.py) ... done
# Collecting timm==0.6.12 (from segmentation-models-pytorch)
#   Downloading timm-0.6.12-py3-none-any.whl (549 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 549.1/549.1 kB 2.2 MB/s eta 0:00:0000:01
# Requirement already satisfied: tqdm in /usr/local/lib/python3.8/dist-packages (from segmentation-models-pytorch) (4.65.0)
# Requirement already satisfied: pillow in /usr/local/lib/python3.8/dist-packages (from segmentation-models-pytorch) (9.5.0)
# Requirement already satisfied: torch in /usr/local/lib/python3.8/dist-packages (from efficientnet-pytorch==0.7.1->segmentation-models-pytorch) (2.0.1)
# Collecting munch (from pretrainedmodels==0.7.4->segmentation-models-pytorch)
#   Downloading munch-3.0.0-py2.py3-none-any.whl (10 kB)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.8/dist-packages (from timm==0.6.12->segmentation-models-pytorch) (6.0)
# Collecting huggingface-hub (from timm==0.6.12->segmentation-models-pytorch)
#   Downloading huggingface_hub-0.14.1-py3-none-any.whl (224 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 224.5/224.5 kB 608.7 kB/s eta 0:00:00a 0:00:01
# Requirement already satisfied: numpy in /usr/local/lib/python3.8/dist-packages (from torchvision>=0.5.0->segmentation-models-pytorch) (1.23.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.8/dist-packages (from torchvision>=0.5.0->segmentation-models-pytorch) (2.30.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.8/dist-packages (from torch->efficientnet-pytorch==0.7.1->segmentation-models-pytorch) (3.12.0)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.8/dist-packages (from torch->efficientnet-pytorch==0.7.1->segmentation-models-pytorch) (4.5.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.8/dist-packages (from torch->efficientnet-pytorch==0.7.1->segmentation-models-pytorch) (1.11.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.8/dist-packages (from torch->efficientnet-pytorch==0.7.1->segmentation-models-pytorch) (3.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.8/dist-packages (from torch->efficientnet-pytorch==0.7.1->segmentation-models-pytorch) (3.1.2)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu11==11.7.99 in /usr/local/lib/python3.8/dist-packages (from torch->efficientnet-pytorch==0.7.1->segmentation-models-pytorch) (11.7.99)
# Requirement already satisfied: nvidia-cuda-runtime-cu11==11.7.99 in /usr/local/lib/python3.8/dist-packages (from torch->efficientnet-pytorch==0.7.1->segmentation-models-pytorch) (11.7.99)
# Requirement already satisfied: nvidia-cuda-cupti-cu11==11.7.101 in /usr/local/lib/python3.8/dist-packages (from torch->efficientnet-pytorch==0.7.1->segmentation-models-pytorch) (11.7.101)
# Requirement already satisfied: nvidia-cudnn-cu11==8.5.0.96 in /usr/local/lib/python3.8/dist-packages (from torch->efficientnet-pytorch==0.7.1->segmentation-models-pytorch) (8.5.0.96)
# Requirement already satisfied: nvidia-cublas-cu11==11.10.3.66 in /usr/local/lib/python3.8/dist-packages (from torch->efficientnet-pytorch==0.7.1->segmentation-models-pytorch) (11.10.3.66)
# Requirement already satisfied: nvidia-cufft-cu11==10.9.0.58 in /usr/local/lib/python3.8/dist-packages (from torch->efficientnet-pytorch==0.7.1->segmentation-models-pytorch) (10.9.0.58)
# Requirement already satisfied: nvidia-curand-cu11==10.2.10.91 in /usr/local/lib/python3.8/dist-packages (from torch->efficientnet-pytorch==0.7.1->segmentation-models-pytorch) (10.2.10.91)
# Requirement already satisfied: nvidia-cusolver-cu11==11.4.0.1 in /usr/local/lib/python3.8/dist-packages (from torch->efficientnet-pytorch==0.7.1->segmentation-models-pytorch) (11.4.0.1)
# Requirement already satisfied: nvidia-cusparse-cu11==11.7.4.91 in /usr/local/lib/python3.8/dist-packages (from torch->efficientnet-pytorch==0.7.1->segmentation-models-pytorch) (11.7.4.91)
# Requirement already satisfied: nvidia-nccl-cu11==2.14.3 in /usr/local/lib/python3.8/dist-packages (from torch->efficientnet-pytorch==0.7.1->segmentation-models-pytorch) (2.14.3)
# Requirement already satisfied: nvidia-nvtx-cu11==11.7.91 in /usr/local/lib/python3.8/dist-packages (from torch->efficientnet-pytorch==0.7.1->segmentation-models-pytorch) (11.7.91)
# Requirement already satisfied: triton==2.0.0 in /usr/local/lib/python3.8/dist-packages (from torch->efficientnet-pytorch==0.7.1->segmentation-models-pytorch) (2.0.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.8/dist-packages (from nvidia-cublas-cu11==11.10.3.66->torch->efficientnet-pytorch==0.7.1->segmentation-models-pytorch) (67.7.2)
# Requirement already satisfied: wheel in /usr/local/lib/python3.8/dist-packages (from nvidia-cublas-cu11==11.10.3.66->torch->efficientnet-pytorch==0.7.1->segmentation-models-pytorch) (0.40.0)
# Requirement already satisfied: cmake in /usr/local/lib/python3.8/dist-packages (from triton==2.0.0->torch->efficientnet-pytorch==0.7.1->segmentation-models-pytorch) (3.26.3)
# Requirement already satisfied: lit in /usr/local/lib/python3.8/dist-packages (from triton==2.0.0->torch->efficientnet-pytorch==0.7.1->segmentation-models-pytorch) (16.0.3)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.8/dist-packages (from huggingface-hub->timm==0.6.12->segmentation-models-pytorch) (2023.5.0)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.8/dist-packages (from huggingface-hub->timm==0.6.12->segmentation-models-pytorch) (23.1)
# Requirement already satisfied: six in /usr/lib/python3/dist-packages (from munch->pretrainedmodels==0.7.4->segmentation-models-pytorch) (1.14.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.8/dist-packages (from requests->torchvision>=0.5.0->segmentation-models-pytorch) (3.1.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/lib/python3/dist-packages (from requests->torchvision>=0.5.0->segmentation-models-pytorch) (2.8)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/jovyan/.local/lib/python3.8/site-packages (from requests->torchvision>=0.5.0->segmentation-models-pytorch) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/lib/python3/dist-packages (from requests->torchvision>=0.5.0->segmentation-models-pytorch) (2019.11.28)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.8/dist-packages (from jinja2->torch->efficientnet-pytorch==0.7.1->segmentation-models-pytorch) (2.1.2)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.8/dist-packages (from sympy->torch->efficientnet-pytorch==0.7.1->segmentation-models-pytorch) (1.3.0)
# Building wheels for collected packages: efficientnet-pytorch, pretrainedmodels
#   Building wheel for efficientnet-pytorch (setup.py) ... done
#   Created wheel for efficientnet-pytorch: filename=efficientnet_pytorch-0.7.1-py3-none-any.whl size=16427 sha256=3cafe1a4f06ee17f5cb85290353a6f80cdf86adce1d92a0453690729ddef6895
#   Stored in directory: /home/jovyan/.cache/pip/wheels/84/b9/90/25a0195cf95fb5533db96f1c77ea3f296b7cc86ae8ae48e3dc
#   Building wheel for pretrainedmodels (setup.py) ... done
#   Created wheel for pretrainedmodels: filename=pretrainedmodels-0.7.4-py3-none-any.whl size=60945 sha256=be83d1616c15683dc3d3ae7cb17ff6edcd5bff584288bb9f91eb40637dd2550c
#   Stored in directory: /home/jovyan/.cache/pip/wheels/ed/fa/b9/5c82b59d905f95542a192b883c0cc0082407ea2f54beb2f9e6
# Successfully built efficientnet-pytorch pretrainedmodels
# Installing collected packages: munch, huggingface-hub, timm, pretrainedmodels, efficientnet-pytorch, segmentation-models-pytorch
#   WARNING: The script huggingface-cli is installed in '/home/jovyan/.local/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
# Successfully installed efficientnet-pytorch-0.7.1 huggingface-hub-0.14.1 munch-3.0.0 pretrainedmodels-0.7.4 segmentation-models-pytorch-0.3.2 timm-0.6.12
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: monai in /home/jovyan/.local/lib/python3.8/site-packages (1.1.0)
# Requirement already satisfied: torch>=1.8 in /usr/local/lib/python3.8/dist-packages (from monai) (2.0.1)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.8/dist-packages (from monai) (1.23.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.8/dist-packages (from torch>=1.8->monai) (3.12.0)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.8/dist-packages (from torch>=1.8->monai) (4.5.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.8/dist-packages (from torch>=1.8->monai) (1.11.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.8/dist-packages (from torch>=1.8->monai) (3.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.8/dist-packages (from torch>=1.8->monai) (3.1.2)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu11==11.7.99 in /usr/local/lib/python3.8/dist-packages (from torch>=1.8->monai) (11.7.99)
# Requirement already satisfied: nvidia-cuda-runtime-cu11==11.7.99 in /usr/local/lib/python3.8/dist-packages (from torch>=1.8->monai) (11.7.99)
# Requirement already satisfied: nvidia-cuda-cupti-cu11==11.7.101 in /usr/local/lib/python3.8/dist-packages (from torch>=1.8->monai) (11.7.101)
# Requirement already satisfied: nvidia-cudnn-cu11==8.5.0.96 in /usr/local/lib/python3.8/dist-packages (from torch>=1.8->monai) (8.5.0.96)
# Requirement already satisfied: nvidia-cublas-cu11==11.10.3.66 in /usr/local/lib/python3.8/dist-packages (from torch>=1.8->monai) (11.10.3.66)
# Requirement already satisfied: nvidia-cufft-cu11==10.9.0.58 in /usr/local/lib/python3.8/dist-packages (from torch>=1.8->monai) (10.9.0.58)
# Requirement already satisfied: nvidia-curand-cu11==10.2.10.91 in /usr/local/lib/python3.8/dist-packages (from torch>=1.8->monai) (10.2.10.91)
# Requirement already satisfied: nvidia-cusolver-cu11==11.4.0.1 in /usr/local/lib/python3.8/dist-packages (from torch>=1.8->monai) (11.4.0.1)
# Requirement already satisfied: nvidia-cusparse-cu11==11.7.4.91 in /usr/local/lib/python3.8/dist-packages (from torch>=1.8->monai) (11.7.4.91)
# Requirement already satisfied: nvidia-nccl-cu11==2.14.3 in /usr/local/lib/python3.8/dist-packages (from torch>=1.8->monai) (2.14.3)
# Requirement already satisfied: nvidia-nvtx-cu11==11.7.91 in /usr/local/lib/python3.8/dist-packages (from torch>=1.8->monai) (11.7.91)
# Requirement already satisfied: triton==2.0.0 in /usr/local/lib/python3.8/dist-packages (from torch>=1.8->monai) (2.0.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.8/dist-packages (from nvidia-cublas-cu11==11.10.3.66->torch>=1.8->monai) (67.7.2)
# Requirement already satisfied: wheel in /usr/local/lib/python3.8/dist-packages (from nvidia-cublas-cu11==11.10.3.66->torch>=1.8->monai) (0.40.0)
# Requirement already satisfied: cmake in /usr/local/lib/python3.8/dist-packages (from triton==2.0.0->torch>=1.8->monai) (3.26.3)
# Requirement already satisfied: lit in /usr/local/lib/python3.8/dist-packages (from triton==2.0.0->torch>=1.8->monai) (16.0.3)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.8/dist-packages (from jinja2->torch>=1.8->monai) (2.1.2)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.8/dist-packages (from sympy->torch>=1.8->monai) (1.3.0)

# %%
import os
import cv2
import glob
import torch
import monai
import numpy as np
from tqdm import tqdm
from torch.utils.data import Dataset, DataLoader
from torchvision import transforms
import SimpleITK as sitk

torch.manual_seed(1024)
np.random.seed(1024)
device = torch.device(
    "cuda:1"
    if torch.cuda.is_available()
    else
    "mps"
    if torch.backends.mps.is_available()
    else "cpu"
)
print(f"Using {device} device")
# Out:
# Using cuda:1 device

# %%
# !gunzip -r ./Dataset/ACDC/database/training/

# %%
def convert_to_npy(source_path):
    """
    Convert the nii file to npz, reduce RAM cost at the creation of dataset

    Args:
        source_path: file path to nii files

    Returns:
    """
    patient_directories = glob.glob(os.path.join(source_path, 'patient*'))
    for patient_dir in patient_directories:
        gt_image_paths = glob.glob(os.path.join(patient_dir, '*_gt.nii'))
        for gt_image_path in gt_image_paths:
            prefix = gt_image_path[:-7]
            image_path = prefix + ".nii"
            gt_image_array = sitk.GetArrayFromImage(sitk.ReadImage(gt_image_path))
            image_array = sitk.GetArrayFromImage(sitk.ReadImage(image_path))
            for i, image in enumerate(image_array):
                np.save(prefix + '_slice' + str(i) + '.npy', image)
            for i, gt_image in enumerate(gt_image_array):
                np.save(prefix + '_slice' + str(i) + '_gt.npy', gt_image)

# %%
convert_to_npy('./Dataset/ACDC/database/training')
# Out:
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x618a370): ./Dataset/ACDC/database/training/patient032/patient032_frame01_gt.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x618a370): ./Dataset/ACDC/database/training/patient032/patient032_frame01_gt.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x62316d0): ./Dataset/ACDC/database/training/patient032/patient032_frame01.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x62316d0): ./Dataset/ACDC/database/training/patient032/patient032_frame01.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x618a370): ./Dataset/ACDC/database/training/patient032/patient032_frame12_gt.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x618a370): ./Dataset/ACDC/database/training/patient032/patient032_frame12_gt.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x62316d0): ./Dataset/ACDC/database/training/patient032/patient032_frame12.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x62316d0): ./Dataset/ACDC/database/training/patient032/patient032_frame12.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x618a370): ./Dataset/ACDC/database/training/patient072/patient072_frame11_gt.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x618a370): ./Dataset/ACDC/database/training/patient072/patient072_frame11_gt.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x62316d0): ./Dataset/ACDC/database/training/patient072/patient072_frame11.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x62316d0): ./Dataset/ACDC/database/training/patient072/patient072_frame11.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x618a370): ./Dataset/ACDC/database/training/patient072/patient072_frame01_gt.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x618a370): ./Dataset/ACDC/database/training/patient072/patient072_frame01_gt.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x62316d0): ./Dataset/ACDC/database/training/patient072/patient072_frame01.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x62316d0): ./Dataset/ACDC/database/training/patient072/patient072_frame01.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x618a370): ./Dataset/ACDC/database/training/patient006/patient006_frame16_gt.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x618a370): ./Dataset/ACDC/database/training/patient006/patient006_frame16_gt.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x62316d0): ./Dataset/ACDC/database/training/patient006/patient006_frame16.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x62316d0): ./Dataset/ACDC/database/training/patient006/patient006_frame16.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x618a370): ./Dataset/ACDC/database/training/patient006/patient006_frame01_gt.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x618a370): ./Dataset/ACDC/database/training/patient006/patient006_frame01_gt.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x62316d0): ./Dataset/ACDC/database/training/patient006/patient006_frame01.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x62316d0): ./Dataset/ACDC/database/training/patient006/patient006_frame01.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x618a370): ./Dataset/ACDC/database/training/patient051/patient051_frame11_gt.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x618a370): ./Dataset/ACDC/database/training/patient051/patient051_frame11_gt.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x62316d0): ./Dataset/ACDC/database/training/patient051/patient051_frame11.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x62316d0): ./Dataset/ACDC/database/training/patient051/patient051_frame11.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x618a370): ./Dataset/ACDC/database/training/patient051/patient051_frame01_gt.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x618a370): ./Dataset/ACDC/database/training/patient051/patient051_frame01_gt.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x62316d0): ./Dataset/ACDC/database/training/patient051/patient051_frame01.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x62316d0): ./Dataset/ACDC/database/training/patient051/patient051_frame01.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x618a370): ./Dataset/ACDC/database/training/patient001/patient001_frame12_gt.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x618a370): ./Dataset/ACDC/database/training/patient001/patient001_frame12_gt.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x62316d0): ./Dataset/ACDC/database/training/patient001/patient001_frame12.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x62316d0): ./Dataset/ACDC/database/training/patient001/patient001_frame12.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x618a370): ./Dataset/ACDC/database/training/patient001/patient001_frame01_gt.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x618a370): ./Dataset/ACDC/database/training/patient001/patient001_frame01_gt.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x62316d0): ./Dataset/ACDC/database/training/patient001/patient001_frame01.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x62316d0): ./Dataset/ACDC/database/training/patient001/patient001_frame01.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x618a370): ./Dataset/ACDC/database/training/patient070/patient070_frame10_gt.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x618a370): ./Dataset/ACDC/database/training/patient070/patient070_frame10_gt.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x62316d0): ./Dataset/ACDC/database/training/patient070/patient070_frame10.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x62316d0): ./Dataset/ACDC/database/training/patient070/patient070_frame10.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x618a370): ./Dataset/ACDC/database/training/patient070/patient070_frame01_gt.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x618a370): ./Dataset/ACDC/database/training/patient070/patient070_frame01_gt.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x62316d0): ./Dataset/ACDC/database/training/patient070/patient070_frame01.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x62316d0): ./Dataset/ACDC/database/training/patient070/patient070_frame01.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x618a370): ./Dataset/ACDC/database/training/patient026/patient026_frame12_gt.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x618a370): ./Dataset/ACDC/database/training/patient026/patient026_frame12_gt.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x62316d0): ./Dataset/ACDC/database/training/patient026/patient026_frame12.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x62316d0): ./Dataset/ACDC/database/training/patient026/patient026_frame12.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x618a370): ./Dataset/ACDC/database/training/patient026/patient026_frame01_gt.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x618a370): ./Dataset/ACDC/database/training/patient026/patient026_frame01_gt.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x62316d0): ./Dataset/ACDC/database/training/patient026/patient026_frame01.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x62316d0): ./Dataset/ACDC/database/training/patient026/patient026_frame01.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x618a370): ./Dataset/ACDC/database/training/patient010/patient010_frame01_gt.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x618a370): ./Dataset/ACDC/database/training/patient010/patient010_frame01_gt.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x62316d0): ./Dataset/ACDC/database/training/patient010/patient010_frame01.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x62316d0): ./Dataset/ACDC/database/training/patient010/patient010_frame01.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x618a370): ./Dataset/ACDC/database/training/patient010/patient010_frame13_gt.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x618a370): ./Dataset/ACDC/database/training/patient010/patient010_frame13_gt.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x62316d0): ./Dataset/ACDC/database/training/patient010/patient010_frame13.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x62316d0): ./Dataset/ACDC/database/training/patient010/patient010_frame13.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x618a370): ./Dataset/ACDC/database/training/patient068/patient068_frame12_gt.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x618a370): ./Dataset/ACDC/database/training/patient068/patient068_frame12_gt.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x62316d0): ./Dataset/ACDC/database/training/patient068/patient068_frame12.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x62316d0): ./Dataset/ACDC/database/training/patient068/patient068_frame12.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x618a370): ./Dataset/ACDC/database/training/patient068/patient068_frame01_gt.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x618a370): ./Dataset/ACDC/database/training/patient068/patient068_frame01_gt.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x62316d0): ./Dataset/ACDC/database/training/patient068/patient068_frame01.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x62316d0): ./Dataset/ACDC/database/training/patient068/patient068_frame01.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x618a370): ./Dataset/ACDC/database/training/patient050/patient050_frame01_gt.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x618a370): ./Dataset/ACDC/database/training/patient050/patient050_frame01_gt.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x62316d0): ./Dataset/ACDC/database/training/patient050/patient050_frame01.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x62316d0): ./Dataset/ACDC/database/training/patient050/patient050_frame01.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x618a370): ./Dataset/ACDC/database/training/patient050/patient050_frame12_gt.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x618a370): ./Dataset/ACDC/database/training/patient050/patient050_frame12_gt.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x62316d0): ./Dataset/ACDC/database/training/patient050/patient050_frame12.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x62316d0): ./Dataset/ACDC/database/training/patient050/patient050_frame12.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x618a370): ./Dataset/ACDC/database/training/patient096/patient096_frame08_gt.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x618a370): ./Dataset/ACDC/database/training/patient096/patient096_frame08_gt.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x62316d0): ./Dataset/ACDC/database/training/patient096/patient096_frame08.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x62316d0): ./Dataset/ACDC/database/training/patient096/patient096_frame08.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x618a370): ./Dataset/ACDC/database/training/patient096/patient096_frame01_gt.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x618a370): ./Dataset/ACDC/database/training/patient096/patient096_frame01_gt.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x62316d0): ./Dataset/ACDC/database/training/patient096/patient096_frame01.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x62316d0): ./Dataset/ACDC/database/training/patient096/patient096_frame01.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x618a370): ./Dataset/ACDC/database/training/patient009/patient009_frame13_gt.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x618a370): ./Dataset/ACDC/database/training/patient009/patient009_frame13_gt.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x62316d0): ./Dataset/ACDC/database/training/patient009/patient009_frame13.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x62316d0): ./Dataset/ACDC/database/training/patient009/patient009_frame13.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x618a370): ./Dataset/ACDC/database/training/patient009/patient009_frame01_gt.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x618a370): ./Dataset/ACDC/database/training/patient009/patient009_frame01_gt.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x62316d0): ./Dataset/ACDC/database/training/patient009/patient009_frame01.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x62316d0): ./Dataset/ACDC/database/training/patient009/patient009_frame01.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x618a370): ./Dataset/ACDC/database/training/patient091/patient091_frame01_gt.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x618a370): ./Dataset/ACDC/database/training/patient091/patient091_frame01_gt.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x62316d0): ./Dataset/ACDC/database/training/patient091/patient091_frame01.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x62316d0): ./Dataset/ACDC/database/training/patient091/patient091_frame01.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x618a370): ./Dataset/ACDC/database/training/patient091/patient091_frame09_gt.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x618a370): ./Dataset/ACDC/database/training/patient091/patient091_frame09_gt.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x62316d0): ./Dataset/ACDC/database/training/patient091/patient091_frame09.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x62316d0): ./Dataset/ACDC/database/training/patient091/patient091_frame09.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x618a370): ./Dataset/ACDC/database/training/patient024/patient024_frame09_gt.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x618a370): ./Dataset/ACDC/database/training/patient024/patient024_frame09_gt.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x62316d0): ./Dataset/ACDC/database/training/patient024/patient024_frame09.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x62316d0): ./Dataset/ACDC/database/training/patient024/patient024_frame09.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x618a370): ./Dataset/ACDC/database/training/patient024/patient024_frame01_gt.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x618a370): ./Dataset/ACDC/database/training/patient024/patient024_frame01_gt.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x62316d0): ./Dataset/ACDC/database/training/patient024/patient024_frame01.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x62316d0): ./Dataset/ACDC/database/training/patient024/patient024_frame01.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x618a370): ./Dataset/ACDC/database/training/patient058/patient058_frame01_gt.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x618a370): ./Dataset/ACDC/database/training/patient058/patient058_frame01_gt.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x62316d0): ./Dataset/ACDC/database/training/patient058/patient058_frame01.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x62316d0): ./Dataset/ACDC/database/training/patient058/patient058_frame01.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x618a370): ./Dataset/ACDC/database/training/patient058/patient058_frame14_gt.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x618a370): ./Dataset/ACDC/database/training/patient058/patient058_frame14_gt.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x62316d0): ./Dataset/ACDC/database/training/patient058/patient058_frame14.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x62316d0): ./Dataset/ACDC/database/training/patient058/patient058_frame14.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x618a370): ./Dataset/ACDC/database/training/patient065/patient065_frame01_gt.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x618a370): ./Dataset/ACDC/database/training/patient065/patient065_frame01_gt.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x62316d0): ./Dataset/ACDC/database/training/patient065/patient065_frame01.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x62316d0): ./Dataset/ACDC/database/training/patient065/patient065_frame01.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x618a370): ./Dataset/ACDC/database/training/patient065/patient065_frame14_gt.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x618a370): ./Dataset/ACDC/database/training/patient065/patient065_frame14_gt.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x62316d0): ./Dataset/ACDC/database/training/patient065/patient065_frame14.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x62316d0): ./Dataset/ACDC/database/training/patient065/patient065_frame14.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x618a370): ./Dataset/ACDC/database/training/patient037/patient037_frame12_gt.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x618a370): ./Dataset/ACDC/database/training/patient037/patient037_frame12_gt.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x62316d0): ./Dataset/ACDC/database/training/patient037/patient037_frame12.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x62316d0): ./Dataset/ACDC/database/training/patient037/patient037_frame12.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x618a370): ./Dataset/ACDC/database/training/patient037/patient037_frame01_gt.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x618a370): ./Dataset/ACDC/database/training/patient037/patient037_frame01_gt.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x62316d0): ./Dataset/ACDC/database/training/patient037/patient037_frame01.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x62316d0): ./Dataset/ACDC/database/training/patient037/patient037_frame01.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x618a370): ./Dataset/ACDC/database/training/patient031/patient031_frame10_gt.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x618a370): ./Dataset/ACDC/database/training/patient031/patient031_frame10_gt.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x62316d0): ./Dataset/ACDC/database/training/patient031/patient031_frame10.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x62316d0): ./Dataset/ACDC/database/training/patient031/patient031_frame10.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x618a370): ./Dataset/ACDC/database/training/patient031/patient031_frame01_gt.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x618a370): ./Dataset/ACDC/database/training/patient031/patient031_frame01_gt.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x62316d0): ./Dataset/ACDC/database/training/patient031/patient031_frame01.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x62316d0): ./Dataset/ACDC/database/training/patient031/patient031_frame01.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x618a370): ./Dataset/ACDC/database/training/patient094/patient094_frame01_gt.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x618a370): ./Dataset/ACDC/database/training/patient094/patient094_frame01_gt.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x62316d0): ./Dataset/ACDC/database/training/patient094/patient094_frame01.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x62316d0): ./Dataset/ACDC/database/training/patient094/patient094_frame01.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x618a370): ./Dataset/ACDC/database/training/patient094/patient094_frame07_gt.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x618a370): ./Dataset/ACDC/database/training/patient094/patient094_frame07_gt.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x62316d0): ./Dataset/ACDC/database/training/patient094/patient094_frame07.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x62316d0): ./Dataset/ACDC/database/training/patient094/patient094_frame07.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x618a370): ./Dataset/ACDC/database/training/patient039/patient039_frame01_gt.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x618a370): ./Dataset/ACDC/database/training/patient039/patient039_frame01_gt.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x62316d0): ./Dataset/ACDC/database/training/patient039/patient039_frame01.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x62316d0): ./Dataset/ACDC/database/training/patient039/patient039_frame01.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x618a370): ./Dataset/ACDC/database/training/patient039/patient039_frame10_gt.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x618a370): ./Dataset/ACDC/database/training/patient039/patient039_frame10_gt.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x62316d0): ./Dataset/ACDC/database/training/patient039/patient039_frame10.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x62316d0): ./Dataset/ACDC/database/training/patient039/patient039_frame10.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x618a370): ./Dataset/ACDC/database/training/patient035/patient035_frame11_gt.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x618a370): ./Dataset/ACDC/database/training/patient035/patient035_frame11_gt.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x62316d0): ./Dataset/ACDC/database/training/patient035/patient035_frame11.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x62316d0): ./Dataset/ACDC/database/training/patient035/patient035_frame11.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x618a370): ./Dataset/ACDC/database/training/patient035/patient035_frame01_gt.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x618a370): ./Dataset/ACDC/database/training/patient035/patient035_frame01_gt.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x62316d0): ./Dataset/ACDC/database/training/patient035/patient035_frame01.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x62316d0): ./Dataset/ACDC/database/training/patient035/patient035_frame01.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x618a370): ./Dataset/ACDC/database/training/patient087/patient087_frame01_gt.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x618a370): ./Dataset/ACDC/database/training/patient087/patient087_frame01_gt.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x62316d0): ./Dataset/ACDC/database/training/patient087/patient087_frame01.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x62316d0): ./Dataset/ACDC/database/training/patient087/patient087_frame01.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x618a370): ./Dataset/ACDC/database/training/patient087/patient087_frame10_gt.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x618a370): ./Dataset/ACDC/database/training/patient087/patient087_frame10_gt.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x62316d0): ./Dataset/ACDC/database/training/patient087/patient087_frame10.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x62316d0): ./Dataset/ACDC/database/training/patient087/patient087_frame10.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x618a370): ./Dataset/ACDC/database/training/patient060/patient060_frame01_gt.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x618a370): ./Dataset/ACDC/database/training/patient060/patient060_frame01_gt.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x62316d0): ./Dataset/ACDC/database/training/patient060/patient060_frame01.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x62316d0): ./Dataset/ACDC/database/training/patient060/patient060_frame01.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x618a370): ./Dataset/ACDC/database/training/patient060/patient060_frame14_gt.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x618a370): ./Dataset/ACDC/database/training/patient060/patient060_frame14_gt.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x62316d0): ./Dataset/ACDC/database/training/patient060/patient060_frame14.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x62316d0): ./Dataset/ACDC/database/training/patient060/patient060_frame14.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x618a370): ./Dataset/ACDC/database/training/patient002/patient002_frame01_gt.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x618a370): ./Dataset/ACDC/database/training/patient002/patient002_frame01_gt.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x62316d0): ./Dataset/ACDC/database/training/patient002/patient002_frame01.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x62316d0): ./Dataset/ACDC/database/training/patient002/patient002_frame01.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x618a370): ./Dataset/ACDC/database/training/patient002/patient002_frame12_gt.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x618a370): ./Dataset/ACDC/database/training/patient002/patient002_frame12_gt.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x62316d0): ./Dataset/ACDC/database/training/patient002/patient002_frame12.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x62316d0): ./Dataset/ACDC/database/training/patient002/patient002_frame12.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x618a370): ./Dataset/ACDC/database/training/patient011/patient011_frame01_gt.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x618a370): ./Dataset/ACDC/database/training/patient011/patient011_frame01_gt.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x62316d0): ./Dataset/ACDC/database/training/patient011/patient011_frame01.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x62316d0): ./Dataset/ACDC/database/training/patient011/patient011_frame01.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x618a370): ./Dataset/ACDC/database/training/patient011/patient011_frame08_gt.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x618a370): ./Dataset/ACDC/database/training/patient011/patient011_frame08_gt.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x62316d0): ./Dataset/ACDC/database/training/patient011/patient011_frame08.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x62316d0): ./Dataset/ACDC/database/training/patient011/patient011_frame08.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x618a370): ./Dataset/ACDC/database/training/patient084/patient084_frame10_gt.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x618a370): ./Dataset/ACDC/database/training/patient084/patient084_frame10_gt.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x62316d0): ./Dataset/ACDC/database/training/patient084/patient084_frame10.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x62316d0): ./Dataset/ACDC/database/training/patient084/patient084_frame10.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x618a370): ./Dataset/ACDC/database/training/patient084/patient084_frame01_gt.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x618a370): ./Dataset/ACDC/database/training/patient084/patient084_frame01_gt.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x62316d0): ./Dataset/ACDC/database/training/patient084/patient084_frame01.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x62316d0): ./Dataset/ACDC/database/training/patient084/patient084_frame01.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x618a370): ./Dataset/ACDC/database/training/patient055/patient055_frame10_gt.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x618a370): ./Dataset/ACDC/database/training/patient055/patient055_frame10_gt.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x62316d0): ./Dataset/ACDC/database/training/patient055/patient055_frame10.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x62316d0): ./Dataset/ACDC/database/training/patient055/patient055_frame10.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x618a370): ./Dataset/ACDC/database/training/patient055/patient055_frame01_gt.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x618a370): ./Dataset/ACDC/database/training/patient055/patient055_frame01_gt.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x62316d0): ./Dataset/ACDC/database/training/patient055/patient055_frame01.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x62316d0): ./Dataset/ACDC/database/training/patient055/patient055_frame01.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x618a370): ./Dataset/ACDC/database/training/patient048/patient048_frame01_gt.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x618a370): ./Dataset/ACDC/database/training/patient048/patient048_frame01_gt.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x62316d0): ./Dataset/ACDC/database/training/patient048/patient048_frame01.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x62316d0): ./Dataset/ACDC/database/training/patient048/patient048_frame01.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x618a370): ./Dataset/ACDC/database/training/patient048/patient048_frame08_gt.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x618a370): ./Dataset/ACDC/database/training/patient048/patient048_frame08_gt.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# ...
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x62316d0): ./Dataset/ACDC/database/training/patient038/patient038_frame11.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x62316d0): ./Dataset/ACDC/database/training/patient038/patient038_frame11.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x618a370): ./Dataset/ACDC/database/training/patient029/patient029_frame12_gt.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x618a370): ./Dataset/ACDC/database/training/patient029/patient029_frame12_gt.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x62316d0): ./Dataset/ACDC/database/training/patient029/patient029_frame12.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x62316d0): ./Dataset/ACDC/database/training/patient029/patient029_frame12.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x618a370): ./Dataset/ACDC/database/training/patient029/patient029_frame01_gt.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x618a370): ./Dataset/ACDC/database/training/patient029/patient029_frame01_gt.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x62316d0): ./Dataset/ACDC/database/training/patient029/patient029_frame01.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x62316d0): ./Dataset/ACDC/database/training/patient029/patient029_frame01.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x618a370): ./Dataset/ACDC/database/training/patient016/patient016_frame12_gt.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x618a370): ./Dataset/ACDC/database/training/patient016/patient016_frame12_gt.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x62316d0): ./Dataset/ACDC/database/training/patient016/patient016_frame12.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x62316d0): ./Dataset/ACDC/database/training/patient016/patient016_frame12.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x618a370): ./Dataset/ACDC/database/training/patient016/patient016_frame01_gt.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x618a370): ./Dataset/ACDC/database/training/patient016/patient016_frame01_gt.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x62316d0): ./Dataset/ACDC/database/training/patient016/patient016_frame01.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x62316d0): ./Dataset/ACDC/database/training/patient016/patient016_frame01.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x618a370): ./Dataset/ACDC/database/training/patient044/patient044_frame11_gt.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x618a370): ./Dataset/ACDC/database/training/patient044/patient044_frame11_gt.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x62316d0): ./Dataset/ACDC/database/training/patient044/patient044_frame11.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x62316d0): ./Dataset/ACDC/database/training/patient044/patient044_frame11.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x618a370): ./Dataset/ACDC/database/training/patient044/patient044_frame01_gt.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x618a370): ./Dataset/ACDC/database/training/patient044/patient044_frame01_gt.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x62316d0): ./Dataset/ACDC/database/training/patient044/patient044_frame01.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x62316d0): ./Dataset/ACDC/database/training/patient044/patient044_frame01.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x618a370): ./Dataset/ACDC/database/training/patient057/patient057_frame09_gt.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x618a370): ./Dataset/ACDC/database/training/patient057/patient057_frame09_gt.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x62316d0): ./Dataset/ACDC/database/training/patient057/patient057_frame09.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x62316d0): ./Dataset/ACDC/database/training/patient057/patient057_frame09.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x618a370): ./Dataset/ACDC/database/training/patient057/patient057_frame01_gt.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x618a370): ./Dataset/ACDC/database/training/patient057/patient057_frame01_gt.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x62316d0): ./Dataset/ACDC/database/training/patient057/patient057_frame01.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x62316d0): ./Dataset/ACDC/database/training/patient057/patient057_frame01.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x618a370): ./Dataset/ACDC/database/training/patient025/patient025_frame01_gt.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x618a370): ./Dataset/ACDC/database/training/patient025/patient025_frame01_gt.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x62316d0): ./Dataset/ACDC/database/training/patient025/patient025_frame01.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x62316d0): ./Dataset/ACDC/database/training/patient025/patient025_frame01.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x618a370): ./Dataset/ACDC/database/training/patient025/patient025_frame09_gt.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x618a370): ./Dataset/ACDC/database/training/patient025/patient025_frame09_gt.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x62316d0): ./Dataset/ACDC/database/training/patient025/patient025_frame09.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x62316d0): ./Dataset/ACDC/database/training/patient025/patient025_frame09.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x618a370): ./Dataset/ACDC/database/training/patient007/patient007_frame07_gt.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x618a370): ./Dataset/ACDC/database/training/patient007/patient007_frame07_gt.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x62316d0): ./Dataset/ACDC/database/training/patient007/patient007_frame07.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x62316d0): ./Dataset/ACDC/database/training/patient007/patient007_frame07.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x618a370): ./Dataset/ACDC/database/training/patient007/patient007_frame01_gt.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x618a370): ./Dataset/ACDC/database/training/patient007/patient007_frame01_gt.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x62316d0): ./Dataset/ACDC/database/training/patient007/patient007_frame01.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x62316d0): ./Dataset/ACDC/database/training/patient007/patient007_frame01.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x618a370): ./Dataset/ACDC/database/training/patient080/patient080_frame10_gt.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x618a370): ./Dataset/ACDC/database/training/patient080/patient080_frame10_gt.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x62316d0): ./Dataset/ACDC/database/training/patient080/patient080_frame10.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x62316d0): ./Dataset/ACDC/database/training/patient080/patient080_frame10.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x618a370): ./Dataset/ACDC/database/training/patient080/patient080_frame01_gt.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x618a370): ./Dataset/ACDC/database/training/patient080/patient080_frame01_gt.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x62316d0): ./Dataset/ACDC/database/training/patient080/patient080_frame01.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x62316d0): ./Dataset/ACDC/database/training/patient080/patient080_frame01.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x618a370): ./Dataset/ACDC/database/training/patient019/patient019_frame11_gt.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x618a370): ./Dataset/ACDC/database/training/patient019/patient019_frame11_gt.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x62316d0): ./Dataset/ACDC/database/training/patient019/patient019_frame11.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x62316d0): ./Dataset/ACDC/database/training/patient019/patient019_frame11.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x618a370): ./Dataset/ACDC/database/training/patient019/patient019_frame01_gt.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x618a370): ./Dataset/ACDC/database/training/patient019/patient019_frame01_gt.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x62316d0): ./Dataset/ACDC/database/training/patient019/patient019_frame01.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x62316d0): ./Dataset/ACDC/database/training/patient019/patient019_frame01.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x618a370): ./Dataset/ACDC/database/training/patient017/patient017_frame01_gt.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x618a370): ./Dataset/ACDC/database/training/patient017/patient017_frame01_gt.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x62316d0): ./Dataset/ACDC/database/training/patient017/patient017_frame01.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x62316d0): ./Dataset/ACDC/database/training/patient017/patient017_frame01.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x618a370): ./Dataset/ACDC/database/training/patient017/patient017_frame09_gt.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x618a370): ./Dataset/ACDC/database/training/patient017/patient017_frame09_gt.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x62316d0): ./Dataset/ACDC/database/training/patient017/patient017_frame09.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x62316d0): ./Dataset/ACDC/database/training/patient017/patient017_frame09.nii has unexpected scales in sform

# %%
class SegDataset(Dataset):
    def __init__(self, data_root, transform=None, train=True):
        self.data_root = data_root
        self.transform = transform
        self.train = train
        self.gt_files_path = []
        # find all patient directories
        patient_directories = glob.glob(os.path.join(self.data_root, 'patient*'))
        # find all files with the suffix _gt.npy
        for patient_directory in patient_directories:
            per_patient_file_path = glob.glob(os.path.join(patient_directory, '*_gt.npy'))
            for path in per_patient_file_path:
                self.gt_files_path.append(path)
        
    def __len__(self):
        return len(self.gt_files_path)
    
    def __getitem__(self, index):
        gt_image_path = self.gt_files_path[index]
        image_path = gt_image_path[:-7] + ".npy"
        image = np.load(image_path)
        gt_image = np.load(gt_image_path)
        image = torch.tensor(image[None,:,:]).float()
        gt_image = torch.tensor(gt_image).long()
            
        # Convert the ground truth label to one-hot encoding
        one_hot_label = torch.nn.functional.one_hot(gt_image, num_classes=4)

        # Transpose the tensor to have dimensions (C, H, W)
        one_hot_label = one_hot_label.permute(2, 0, 1)

        # Remove the background channel (dimension 0)
        one_hot_label = one_hot_label[1:, :, :]
        
        transform = transforms.Resize([224, 224])
        
        return transform(image), transform(one_hot_label)

# %%
# transform = transforms.Compose([
#     transforms.Resize([224, 224]),
#     transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
# ])

dataset = SegDataset(data_root = './Dataset/ACDC/database/training')
dataloader = DataLoader(dataset, batch_size=8, shuffle=True)
print(len(dataset))
for img, gt in dataloader:
    # img: (B, 256, 64, 64), {: (B, 1, 256, 256)
    print(f"{img.shape=}, {gt.shape=}")
    break
# Out:
# 1902
# img.shape=torch.Size([8, 1, 224, 224]), gt.shape=torch.Size([8, 3, 224, 224])

# %%
import segmentation_models_pytorch as smp
from segmentation_models_pytorch.encoders import get_preprocessing_fn

model = smp.Unet(
    encoder_name="resnet50",        # choose encoder, e.g. mobilenet_v2 or efficientnet-b7
    encoder_weights="imagenet",     # use `imagenet` pre-trained weights for encoder initialization
    in_channels=1,                  # model input channels (1 for gray-scale images, 3 for RGB, etc.)
    classes=3,                      # model output channels (number of classes in your dataset)
)

preprocess_input = get_preprocessing_fn('resnet50', pretrained='imagenet')

model.to(device)
# Out:
# Unet(
#   (encoder): ResNetEncoder(
#     (conv1): Conv2d(1, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#     (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (relu): ReLU(inplace=True)
#     (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#     (layer1): Sequential(
#       (0): Bottleneck(
#         (conv1): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (downsample): Sequential(
#           (0): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (1): Bottleneck(
#         (conv1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (2): Bottleneck(
#         (conv1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#     )
#     (layer2): Sequential(
#       (0): Bottleneck(
#         (conv1): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (downsample): Sequential(
#           (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#           (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (1): Bottleneck(
#         (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (2): Bottleneck(
#         (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (3): Bottleneck(
#         (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#     )
#     (layer3): Sequential(
#       (0): Bottleneck(
#         (conv1): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (downsample): Sequential(
#           (0): Conv2d(512, 1024, kernel_size=(1, 1), stride=(2, 2), bias=False)
#           (1): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (1): Bottleneck(
#         (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (2): Bottleneck(
#         (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (3): Bottleneck(
#         (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (4): Bottleneck(
#         (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (5): Bottleneck(
#         (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#     )
#     (layer4): Sequential(
#       (0): Bottleneck(
#         (conv1): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (downsample): Sequential(
#           (0): Conv2d(1024, 2048, kernel_size=(1, 1), stride=(2, 2), bias=False)
#           (1): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (1): Bottleneck(
#         (conv1): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (2): Bottleneck(
#         (conv1): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#     )
#   )
#   (decoder): UnetDecoder(
#     (center): Identity()
#     (blocks): ModuleList(
#       (0): DecoderBlock(
#         (conv1): Conv2dReLU(
#           (0): Conv2d(3072, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU(inplace=True)
#         )
#         (attention1): Attention(
#           (attention): Identity()
#         )
#         (conv2): Conv2dReLU(
#           (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU(inplace=True)
#         )
#         (attention2): Attention(
#           (attention): Identity()
#         )
#       )
#       (1): DecoderBlock(
#         (conv1): Conv2dReLU(
#           (0): Conv2d(768, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU(inplace=True)
#         )
#         (attention1): Attention(
#           (attention): Identity()
#         )
#         (conv2): Conv2dReLU(
#           (0): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU(inplace=True)
#         )
#         (attention2): Attention(
#           (attention): Identity()
#         )
#       )
#       (2): DecoderBlock(
#         (conv1): Conv2dReLU(
#           (0): Conv2d(384, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU(inplace=True)
#         )
#         (attention1): Attention(
#           (attention): Identity()
#         )
#         (conv2): Conv2dReLU(
#           (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU(inplace=True)
#         )
#         (attention2): Attention(
#           (attention): Identity()
#         )
#       )
#       (3): DecoderBlock(
#         (conv1): Conv2dReLU(
#           (0): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU(inplace=True)
#         )
#         (attention1): Attention(
#           (attention): Identity()
#         )
#         (conv2): Conv2dReLU(
#           (0): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU(inplace=True)
#         )
#         (attention2): Attention(
#           (attention): Identity()
#         )
#       )
#       (4): DecoderBlock(
#         (conv1): Conv2dReLU(
#           (0): Conv2d(32, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (1): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU(inplace=True)
#         )
#         (attention1): Attention(
#           (attention): Identity()
#         )
#         (conv2): Conv2dReLU(
#           (0): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (1): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU(inplace=True)
#         )
#         (attention2): Attention(
#           (attention): Identity()
#         )
#       )
#     )
#   )
#   (segmentation_head): SegmentationHead(
#     (0): Conv2d(16, 3, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): Identity()
#     (2): Activation(
#       (activation): Identity()
#     )
#   )
# )

# %%
# Set up the optimizer, hyperparameter tuning will improve performance here
optimizer = torch.optim.Adam(model.parameters(), lr=1e-4, weight_decay=0)
seg_loss = monai.losses.DiceCELoss(sigmoid=True, squared_pred=True, reduction='mean')

# %%
#%% train
num_epochs = 20
losses = []
best_loss = 1e10
model.train()
for epoch in range(num_epochs):
    epoch_loss = 0
    # train
    for step, (img, gt) in enumerate(tqdm(dataloader)):
        img = img.to(device)
        mask = model(img)
        loss = seg_loss(mask, gt.to(device))
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        epoch_loss += loss.item()
    
    epoch_loss /= step
    losses.append(epoch_loss)
    print(f'EPOCH: {epoch}, Loss: {epoch_loss}')
    # save the best model
    if epoch_loss < best_loss:
        best_loss = epoch_loss
        torch.save(model.state_dict(), './model/unet-test/model_best.pth')
# Out:
# 100%|██████████| 238/238 [00:51<00:00,  4.62it/s]
# EPOCH: 0, Loss: 0.4753031725621928
# 100%|██████████| 238/238 [00:50<00:00,  4.69it/s]
# EPOCH: 1, Loss: 0.43728912304222334
